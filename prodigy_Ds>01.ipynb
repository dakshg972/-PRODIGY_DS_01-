# %% [markdown]
# <a href="https://colab.research.google.com/github/dakshg972/-PRODIGY_DS_01-/blob/main/prodigy_Ds%3E01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Sample data - replace this with your own dataset
ages = np.random.randint(20, 80, size=100)

# %%
ages
# Out:
# array([47, 71, 55, 63, 51, 53, 21, 48, 67, 29, 55, 59, 48, 30, 59, 37, 45,
#        49, 61, 58, 36, 43, 60, 45, 76, 74, 55, 49, 28, 25, 62, 61, 79, 78,
#        28, 67, 79, 71, 70, 23, 26, 77, 60, 39, 45, 49, 64, 76, 24, 75, 29,
#        52, 40, 68, 42, 67, 34, 28, 74, 53, 76, 49, 59, 38, 32, 54, 45, 56,
#        25, 32, 76, 37, 54, 21, 75, 23, 72, 24, 61, 77, 47, 57, 29, 49, 76,
#        50, 76, 56, 63, 74, 35, 58, 77, 48, 65, 42, 52, 50, 61, 60])

# %%
#create a histogram
plt.hist(ages, bins=10, color = 'skyblue', edgecolor  = 'black')
# Out:
# (array([ 9.,  9.,  6.,  5., 14., 12., 15.,  8.,  5., 17.]),
#  array([21. , 26.8, 32.6, 38.4, 44.2, 50. , 55.8, 61.6, 67.4, 73.2, 79. ]),
#  <BarContainer object of 10 artists>)

# %%
#add title, labels
plt.hist(ages, bins=10, color = 'skyblue', edgecolor  = 'black')
plt.title('Distribution of Ages in a Population')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
#Sample data - replace this with your own dataset
genders = ['Male', 'Female', 'Non-Binary', 'Other']
counts = [140, 170, 40, 20]

# %%
# create a bar chart
plt.bar(genders, counts, color = ['blue', 'purple', 'pink', 'red'])
# Out:
# <BarContainer object of 4 artists>

# %%
#ADD title and labels
plt.bar(genders, counts, color = ['blue', 'purple', 'pink', 'red'])
plt.title('Distribution of Genders in a Population')
plt.xlabel('gender')
plt.ylabel('count')
plt.show()
